# %%
import pickle

# %%
loaded_model=pickle.load(open("finalized_multiple_model.sav",'rb'))
result=loaded_model.predict([[564,354,8765,0,1]])
# Out:
# C:\Anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([[44022.30019118]])
