# %%
# Phase 2 deployment

# %%
import pickle # Import the pickle library to loads the saved model.

# %%
loaded_model=pickle.load(open("finalized_model_linear.sav",'rb')) # Load the linearRegression model from the file. 
result=loaded_model.predict([[0]]) # Predict the salary for 0 years of experience using the loaded model.
# Out:
# C:\Anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
result # Display the predicted salary.
# Out:
# array([[26777.3913412]])
